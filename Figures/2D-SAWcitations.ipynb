# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.arange(2010, 2024, 1)

y = [136,107,132,159,299,548,789,1388,1831,2349,2843,3417,3354,3507]


plt.plot(x, y)

# %%
print(x)
# Out:
# [2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020
#  2021 2022 2023 2024]
