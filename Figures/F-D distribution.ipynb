# %%
import matplotlib.pyplot as plt
import numpy as np

def f(E,T, Ef):
    return 1/(np.exp((E-Ef)/T)+1)


x = np.arange(-10,10,0.001)

plt.figure(figsize = (2,4))
plt.plot(x, f(x,1, 1), color = "black")
plt.axvline(1)


plt.savefig("F-D dist.svg")
